# %% [markdown]
# ## **THEORY QUESTIONS -

# %% [markdown]
# ## **Theory Questions:**

# %% [markdown]
# ### **1.What is the difference between a function and a method in Python?**
#
# In Python,a function is a reusable block of code that performs a specific task, while a method is a function that is associated with an object or a class .
#
# Functions:-
#
# A function is a block of code that performs a specific task and can be reused throughout a program.
#
# Functions are independent and don't require an object or class to be defined or called.
#
# Functions are called directly by their name, and can accept arguments as input and return values as output.
#
# Do n't requir 'self'.
#
# Examples:
# print(), len(), str(), etc .
#
# Methods:-
#
# A method is a function that is defined within a class and is associated with objects of that class.
#
# Methods are not independent; they are always linked to an object or a class and are called using the dot notation (e.g., object.method() or Class.method()).
#
# When a method is called, the object itself is implicitly passed as the self argument. (require 'self')
#
#
# Methods are like tools that are specifically designed to work with objects or classes. They operate on the object's data and can modify the object's state.

# %% [markdown]
# ### **2.Explain the concept of function arguments and parameters in Python?**
#
# In Python,function arguments are the actual values passed to the function when it's called and function parameters are the variables declared within the function definition, representing the expected input values.
#
# Funtion Parameters -
#
# Parameters are placeholders for the values that will be used by the function. They are defined within the parentheses of the function's definition.
#
# They are local to the function, meaning they only exist within the function's code block.
#
# Example: In the function definition def greet(name):, name is a parameter
#
# Function Arguments:
#
# Arguments are the actual values that are passed to the function when it's called.
#
# Arguments can be any valid Python expression, including variables, literals, or function calls.
#
# Example:
# In the function call greet("Soumya"), "Soumya" is an argument.

# %%
def add_numbers(num1, num2): # num1 and num2 are parameters
    """This function adds two numbers."""
    return num1 + num2

result = add_numbers(4, 1) # 4 and 1 are arguments
print(result)# Output: 5
# Out:
# 5

# %% [markdown]
# ### **3.What are the different ways to define and call a function in Python?**
#
# n Python, functions are defined using the def keyword, followed by the function name, parentheses for potential arguments, and a colon. To call a function, you use its name followed by parentheses, optionally including argument.
# Defining a Function:
#
# def keyword:
#
# This signals the beginning of a function definition.
#
# Function name: Choose a descriptive name for the function.
#
# Parentheses (()): These enclose the function's arguments, which are variables that the function can accept as input.
#
# Colon (:): Marks the end of the function header and indicates the start of the function's code block.
#
# Function body: The indented code block that contains the instructions the function will execute.
#
# return statement: (Optional) This statement specifies the value that the function should return when it finishes.
#
# Indentation: Python uses indentation (typically four spaces) to define code blocks, including function bodies.
# Arguments: Arguments allow you to pass data into the function for processing.
# Return values: Functions can return values, allowing them to provide output or results to the caller.

# %%
def greeting():
  print("Welcome to the Pwskills")
greeting()
# Out:
# Welcome to the Pwskills

# %% [markdown]
# ### **4.What is the purpose of the 'return' statement in a Python function?**
# The purpose of the return statement in a Python function is to signal the end of the function's execution and return a value to the caller.
#
#  It allows functions to produce output by sending back data that can be used in other parts of the program.
#
#  Return statements can return data of any type, including integers, floats, strings, lists, dictionaries, and even other functions.

# %%
#example of return statement in a Python function?
def add_numbers(num1, num2):
    return num1 + num2

result = add_numbers(4, 1)
print(result)
# Out:
# 5

# %% [markdown]
# ### **5.What are iterators in Python and how do they differ from iterables?**
#
# In Python, an iterator is an object that enables traversal through a sequence of data, one element at a time.Iterators are memory-efficient as they generate elements on demand, rather than storing the entire sequence in memory.
#
# An iterator is basically something we can loop over/through and objects being iterable depends on their class having a __iter__ method. For example: On a list we will iterate through all items in the list.
#
# Iterables, on the other hand, provide the data that we want to iterate over.When we use a while or for loop to repeat a piece of code several times,we are actually running an iteration. That is the name given to the process itself.
#
# i.List is an iterable object
#
# ii.Iteration is a process of looping and an iterator is an object representing a stream of data and return the data one by one
#     list = [1, 2,"soumya"]
#     for i in list:
#     print(i)
#
#     output
#     1
#     2
#     soumya

# %% [markdown]
# ### **6.Explain the concept of generators in Python and how they are defined.**
#
# A Python generator function allows you to declare a function that behaves like an iterator, providing a faster and easier way to create iterators. They can be used on an abstract container of data to turn it into an iterable object like lists, dictionaries and strings.
#
# Generators are useful when we want to produce a large sequence of values, but we don't want to store all of them in memory at once.
#
# Generators special type of function which does not return a single value: it returns an iterator object with a sequence of values.

# %% [markdown]
# ### **7.What are the advantages of using generators over regular functions?**
#
# Generators offer several advantages over regular functions, primarily concerning memory efficiency and lazy evaluation. They generate values on demand, one at a time, rather than computing and storing the entire sequence upfront, making them ideal for large or infinite datasets. This also allows for cooperative multitasking, where a generator can pause its execution and resume later.
#
# Memory Efficiency:
# Generators are memory-friendly because they don't create the entire sequence in memory at once. They generate values as needed, which is crucial when dealing with large datasets or infinite streams of data.
#
# Lazy Evaluation:
# Generators evaluate values only when they are needed, rather than upfront. This is beneficial when processing large amounts of data or when the data stream is infinite.

# %% [markdown]
# ### **8.What is a lambda function in Python and when is it typically used?**
#
# In Python, a lambda function is a small, anonymous function that can take any number of arguments but can only have one expression. It's essentially a shorthand way to define a function that you'll likely only use once.
#
# Lambda functions are typically used in situations where you need a quick, simple function for a specific task, especially when passing functions as arguments to other functions like map(), filter(), or sorted(). They help to keep the code concise and avoid the need for a full function definition when a simple operation is sufficient.
#
# Syntax:  lambda arguments: expression.
#
# It mainly use for simple operations and code conciseness .

# %%
#Example of lambda function =

square = lambda x: x ** 2
print(square(5))
#here x = agrument
    # x**2 = expression
    #square = lambda function
# Out:
# 25

# %% [markdown]
# ### **9.Explain the purpose and usage of the map() function in Python.**
#
# The map() function in Python applies a given function to each item in an iterable (like a list, tuple, or set) and returns a map object, which is an iterator. This allows you to transform or process all items in an iterable without needing an explicit for loop.
#
# Executes a specified funtion for each of items of an iterable
#
# syntax : map (func,iterable)
#
# s = ['1', '2', '3', '4']
# res = map(int, s)
# print(list(res))

# %% [markdown]
# ### **10.What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?**
#
# map(), filter(), and reduce() are built-in functions in Python that operate on iterables (like lists, tuples, etc.) and apply a function to the items within. They are often used in functional programming paradigms.
#
#
# map(): Applies a given function to each item of an iterable and returns a new iterable (a map object, which can be converted to a list or tuple) containing the results. It transforms each element individually.
# Python
#
#     numbers = [1, 2, 3, 4]
#     squared_numbers = map(lambda x: x**2, numbers)
#     print(list(squared_numbers))  # Output: [1, 4, 9, 16]
#
#
# filter(): Creates a new iterable containing only the items from the original iterable for which a given function returns True. It selectively keeps elements based on a condition.
# Python
#
#     numbers = [1, 2, 3, 4, 5, 6]
#     even_numbers = filter(lambda x: x % 2 == 0, numbers)
#     print(list(even_numbers))  # Output: [2, 4, 6]
#
# reduce(): Applies a function cumulatively to the items of an iterable, from left to right, so as to reduce the iterable to a single value. It performs an aggregate computation. Note that in Python 3, reduce() is no longer a built-in function and needs to be imported from the functools module.
# Python
#
#     from functools import reduce
#     numbers = [1, 2, 3, 4]
#     product = reduce(lambda x, y: x * y, numbers)
#     print(product)  # Output: 24
# In essence, map() transforms each element, filter() selects elements based on a condition, and reduce() combines elements into a single result.

# %% [markdown]
# 11.Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13] .
#
# ![IMG_4744.jpeg](data:image/jpeg;base64,...)
